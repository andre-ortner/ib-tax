# %%
# 13.07.23 BG - Option STC - Optionsergebnis korrigiert 
# 11.07.23 BG - Neues Feld fxRateToBase aus Trades mit übertragen 
# 09.07.23 BG - Richtiges Umsetzung von "Assignments" 
# 09.07.23 BG - erste Schritte zu MS-Money-Export 
# 08.07.23 BG - Update des Statments , Uniue Key + levelOfDetail 
# 07.07.23 BG - Jede Bewegung, auch wenn 0 Steuer, kommt in die Tax-Tabelle 
# 06.07.23 BG - Balance noch mit ausgegeben 
# 06.07.23 BG - Nur SBUX zur Fehlersuche 
# 06.07.23 BG - amount umgestellt auf BaseCurreny currency ergänzt 
# 05.07.23 BG - umgestellt auf "levelOfDetail" 
# 05.07.23 BG - Abklemmen der Offenen Positionen 
# 05.07.23 BG - Handel ohne Expiry geklärt (= 0 DTE) 
# 05.07.23 BG - Combo-Beschriftung korrigiert 
# 04.07.23 BG - die US-Zeilen werden aus gefilfter (aber bei Money sollen sie auftauchen)
# 02.07.23 BG - Jetzt geht es los, stimmt der Datensatz 23 %s 
# 02.07.23 BG - Close oh23 Positionen - klappt 
# 01.07.23 BG - Idee von Frank:  wir lassen die Statements/Trades, die nicht im virtuellen Depot sind, aus
#                    un markieren diese in der Tabelle "statements", neues Feld txInfo als .. ausgelassen 
# 30.06.23 Bg - weiter Fehler Suche 
# 29.06.23 BG - Daten ohne Positionen / erste Versuche 
# 28.06.23 BG - Mit Fehlerabfrage, wenn es keinen Trade gibt 
# 28.06.23 BG - Stand auf TeFiX - IB Tax Info 
# 28.06.23 BG - STK testweise eingebaut 
# 27.06.23 Bg - Verlust mit - Zeichen 
# 27.06.23 BG - fifo fertig gestellt 
# 26.06.23 BG - fiFo Result für die Steuer ermitteln 
# 25.06.23 BG - erste Ansätze zu SteuerStatements 
# 23.06.23 BG - Umbau auf die neuen Namesgebung der Datenbank + Feldnamen
# 18.06.23 BG - Depot - opopopopopCombo - Erkennung 
# 17.06.23 BG - erster Wurf
#
# Strategie: lese Statmenments / trades ein
#  
# 18.06. - Offene Themen:   # !!!!!! 3/4 -> Combos noch nicht gelöst !!!!! Iron Condor / Butterfly 
# Abstand der Strikes !!! 
# Nettoprämie ermitteln !!!  
# Zuteilung richtig machen !!
#
# 1,1 - Open-Order - in das Depot eintragen (incl. Quantity)  
# Close-Order - 
#  2.1     suche die passende Open-Order
#  2.2     ermittle den Gewinn  
#  2.3     Trage Closed ein
#  2.4     Update die Quantiy, falls 0 lösche den Eintrag im Depot 
#
#
#
#

from datetime import datetime
from decimal import Decimal # 26.06.
import pymysql
import pandas as pd
#import pyodbc  # Datenbankanbindung an Access 

# from quiffen import Qif, QifDataType # 09.07.23 BG - MS-Money Import 
# import quiffen Zu Kompliziert, 




# ---------- Utilities -------------
def calculateDaysToExpiration( trade ):
    print (f"+++ 123 calculatedaysToExpiration- {trade}" ) 
    print (f"+++ 123 calculatedaysToExpiration- Expiry-Date: {trade.expiryDate} - TradeDate: {trade.tradeDate} ")  
    # 05.07.23 z.B. beim Aktienkauf gibt es kein expiryDate 
    if trade.expiryDate == None:
        return 0
    else:   
        daysDelta = trade.expiryDate - trade.tradeDate    
        days = daysDelta.days 
        return days   

def calculateDaysInTrade ( openTrade, trade ):
    print ( openTrade )
    opTradeDate = openTrade.tradeDate
    tradeDate = trade.tradeDate
    print ( f"+++ 128 - calculateDaysInTrade  {opTradeDate}   {tradeDate}")
    daysDelta = trade.tradeDate - openTrade.tradeDate
    return daysDelta.days 

def tradetimeEqual ( trade , lastTrade ) :  
    if lastTrade is None :
        return False
    if trade.IBDateTime == lastTrade.IBDateTime : 
        return True
    else :
        return False
    
def calculateCombo ( dbCursor, statement, trade, lastTrade ):
    if tradetimeEqual (trade, lastTrade ):
        # print (f"+++ 145 calculateCombo ID: {statement.id}")
        # print ( statement ) 
        # print (trade)
        # print (lastTrade) 
        opCombo = f"Combo-{statement.id}"  # Korigiert am 05.07. BG 
        # BPS oder BCS berechnen 
        if ( trade.quantity > 0 ):
            if ( trade.strike < lastTrade.strike):
                zusatz = "BullPS"
            else:
                zusatz = "BullCS"
        else: 
            if ( trade.strike > lastTrade.strike):
                zusatz = "BearPS"
            else:
                zusatz = "BearCS"
        opCombo = zusatz + "-" + opCombo 

        # !!!!!! 3/4 -> Combos noch nicht gelöst !!!!!

        # dann muss der Vorgängerdatensatz auch ein Combo bekommen 
        updateSql = f"UPDATE openPositions SET combo = '{opCombo}'  WHERE transactionID = {lastTrade.transactionID} "
        print ( f"+++ Combo: Update-SQL {updateSql}" )
        dbCursor.execute ( updateSql )
        
    else:
        opCombo = ""
    #print (f"+++ 172 - Combo erzeugen - {combo}")
    return opCombo 

def selectStatement ( dbCursor, transactionID):
    sql = f"SELECT * FROM statements WHERE transactionID = {transactionID}"
    print ( "++ Select Statment " + sql )
    dbCursor.execute ( sql )
    #statement = dbCursor.fetchone () 
    statement = pd.DataFrame(dbCursor.fetchall(),columns=[i[0] for i in dbCursor.description])
    
    #if statement is None: # 28.06.23 Fehlrabfrage 
    if statement.empty:
        statement = None
        print  (f"+++ 172 - selectStatement - Kein Statement gefunden für TransaktionsID: {transactionID}")
    else:
        return statement.T.iloc[:,0]

def updateStatementTxInfo ( dbCursor, statement, txInfo ):
    #sql = f"UPDATE statements SET txInfo = '{txInfo}'    WHERE transactionID = {transactionID} "
    #print ( "+++ 177 -  updateStatment tx Info ", sql)
    #dbCursor.execute ( sql )
    #dbCursor.commit()
    updateStatementField ( dbCursor, statement, txInfo , "txInfo" )


def updateStatementOpInfo ( dbCursor, statement, opInfo ):
    #sql = f"UPDATE statements SET opInfo = '{opInfo}'    WHERE transactionID = {statement.transactionID} AND levelOfDetail = {statement.levelOfDetail}"
    #print ( "+++ 177 -  updateStatment op Info ", sql)
    #dbCursor.execute ( sql )
    #dbCursor.commit()
    updateStatementField ( dbCursor, statement, opInfo , "opInfo" )

def updateStatementField ( dbCursor, statement, str , field ):
    # 08.07.23 BG don´t repeat yourself 
    # 08.07.23 BG Beim Update muss .. levelOfDetail dazu, weil es zwei Datensaetze mit der selben ID gibt  
    sql =  f"UPDATE statements SET {field} = '{str}'    "
    sql += f" WHERE transactionID = {statement.transactionID} AND "
    sql += f" levelOfDetail = '{statement.levelOfDetail}' "
    print ( "+++ 217 -  updateStatmentField op Info ", sql)
    dbCursor.execute ( sql )
    dbConn.commit()

def selectTrade ( dbCursor, transactionID):
    sql = f"SELECT * FROM trades WHERE transactionID = {transactionID}"
    print ( "+++ 191 - Select Trade " + sql )
    dbCursor.execute ( sql )
    #trade = dbCursor.fetchone () 
    trade = pd.DataFrame(dbCursor.fetchall(),columns=[i[0] for i in dbCursor.description])
    
    if trade.empty:
        trade = None
        print  (f"+++ 187 - selectTrade -Kein Trade gefunden für TransaktionsID: {transactionID}")
    else:
        return trade.T.iloc[:,0]
    
def selectOpenTransactionID ( dbCursor, trade ):
    # Suche die älteste Position zu dieser conid (statt Beschreibung)  
    sql = f"SELECT MIN(transactionID) FROM openPositions WHERE conid = {trade.conid} " 
    print ( "++ selectOpenTrade " + sql )
    dbCursor.execute ( sql )
    openTransactionID = dbCursor.fetchone ()[0] 
    print (f"+++ - 196 - selectOpenTransactionID SEL: conid = {trade.conid} gefundene Transactions ID: {openTransactionID}")
    return openTransactionID 

def opGetPositionsCount (dbCursor, conid):
    sql = f"SELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = {conid}"
    print ( "+++ opGetPositionCount" + sql )
    dbCursor.execute ( sql) 
    #zeile = dbCursor.fetchone ()
    zeile = pd.DataFrame(dbCursor.fetchall(),columns=[i[0] for i in dbCursor.description])
    
    print ( zeile )
    anzahl = zeile.anzahl 
    print (f"+++ - 206 - GetPositionsCount WHERE conid = {conid} --> Anzahl {anzahl} ")
    return anzahl 


#-----------------------------------------------
#
# MS-Money / QIF -   09.07.23 - Neustart
#  #
#qif = quiffen.Qif()  
qifBaseCurrency = None 
qifCurrency = None
qifBaseCurrencyAccount = None 
qifCurrencyAccount = None

#    assert transaction.date == datetime(2022, 2, 1)
#    assert transaction.amount == 100
#    assert transaction.check_number == 1
#    assert transaction.payee == "Test Payee"
#    assert transaction.memo == "Test Memo"
#   assert transaction.payee_address == "Test Address"
#    assert transaction.category == Category(name="Test Category")
#    assert transaction.splits == [Split(amount=100)]

def qifInsertTransaction ( statement):
    global qif, qifBaseCurrencyAccount, qifCurrencyAccount
    levelOfDetail = statement.levelOfDetail
    if levelOfDetail == "BaseCurrency":
        if qifBaseCurrency == None:
            a = 1 
            # Ersten Eintrag machen Konto beginnt 
 #           qifBaseCurrencyAccount = quiffen.Account(name='BaseCurrency', desc='BasisAccount', balance = statement.balance)
            #qifBaseCurrencyAccount.balance = statement.balance
  #      tr = quiffen.Transaction ( date = statement.datum , amount = statement.amount,  
   #                         memo = statement.activityDescription, 
    #                        # category = dict(cat="kat", sub="subkategorie"),
     #                       payee = statement.description  )
      #  qifBaseCurrencyAccount.set_header(quiffen.AccountType.BANK)
       # qifBaseCurrencyAccount.add_transaction ( tr ) 
        # qifBaseCurrencyAccount.transactions 
    
    
    if levelOfDetail == "Currency":
        #if qifBaseCurrency == None:
        #    qifCurrencyAccount = quiffen.Account(name='Currency', desc='Account', balance = statement.balance)
            qifBaseCurrencyAccount.balance = statement.balance
        # cat = {cat="kat", sub="subkategorie"}
        #tr = quiffen.Transaction ( date = statement.datum , amount = statement.amount, 
         #                   memo = statement.activityDescription, 
          #                  # category = dict(cat="kat", sub="subkategorie"),
           #                 payee = statement.description )
        #qifCurrencyAccount.set_header(quiffen.AccountType.BANK)
        #qifCurrencyAccount.add_transaction ( tr ) 


#------------ Tax - Utilities ---------------------
# 06.07.23 BG - Neu 
def updateTxAmountCurrency ( dbCursor, statement ):  
    #sql = f"UPDATE statements SET IBcurrency = '{statement.IBcurrency}', amount = {statement.amount}    " 
    #sql += f"WHERE transactionID = {statement.transactionID} "
    #p#rint ( "+++ 238 -  updateTX 2. Währung ", sql)
    
    sql = "UPDATE taxstatements SET IBcurrency = %s, amount = %s , balance = %s WHERE transactionID =  %s  " 
    werte = ( statement.IBcurrency , statement.amount , statement.balance , statement.transactionID)
    print ( f"+++ 238 -  NEU : ID {statement.id} updateTX 2. Währung ", sql, werte )
    #dbCursor.execute ( sql , werte )
    #dbCursor.commit()
    
    # Verzweifelt, keien bessere Lösung 
    id = statement.transactionID
    updateTxField ( dbCursor , "IBcurrency", statement.IBcurrency, id , "S")
    updateTxField ( dbCursor , "amount", statement.amount, id , "I")
    updateTxField ( dbCursor , "balance", statement.balance, id , "I")
    
def updateTxField ( dbCursor , field, value, id , typ):
    if typ == "S" : # String 
        trenner = "'"
    else:
        trenner = " "
    sql = f"UPDATE taxstatements SET {field} = {trenner}{value}{trenner} WHERE transactionID = {id}"
    print ( f"+++ 255 -  NEU : Feldweise {sql}" )
    # print ( "Type von ", type(sql))
    dbCursor.execute ( sql )
    dbConn.commit()



#------- ---------- Open Positions Utilities -------------------
def opSelectTrade ( dbCursor, transactionID):
    sql = f"SELECT * FROM openPositions WHERE transactionID = {transactionID}"
    dbCursor.execute ( sql )
    return dbCursor.fetchone ()  

def opDeleteTrade ( dbCursor, opTrade ):
    transactionID = opTrade.transactionID 
    sql = f"DELETE FROM openPositions WHERE transactionID = {transactionID} "
    print ( f"+++ 218 opDeleteTrade {sql}")
    dbCursor.execute ( sql )
    dbConn.commit()

def opUpdateTrade ( dbCursor, opTrade, openStatement, statement, trade ):
    tradeQuantity = trade.quantity
    opTradeQuantity = opTrade.quantity
    newQuantity =  opTradeQuantity + tradeQuantity 
    newAmount = openStatement.amount + statement.amount 
    transactionID = opTrade.transactionID
    sql = f"UPDATE openPositions SET quantity = {newQuantity}, amount = {newAmount}    WHERE transactionID = {transactionID} "
    print ( f"+++ 228 - {sql}")
    dbCursor.execute ( sql )
    dbConn.commit()


# ------------ Hauptbestandteile ----------------------
def updateOpenPositions ( dbCursor, statement, trade, lastTrade ): # lastTradeTime, lastTransactionID ):
    #print ("Statment: ",statement) 
    #print ("Trade: ", statement, trade) 

    # 1.1 - Open-Order - in das Depot eintragen (incl. Quantity)  
    if trade.openClose == "Open":
        opInsertOpenTrade ( dbCursor, statement, trade , lastTrade )
        opAmount = statement.amount # Wenn Option, dann haben wir schon einen Gewinn  
        return 0   
            
    elif trade.openClose == "Close":
        # Close-Order - 
        print ("+++ 282 ---- Hier kommt die Close-Order" , trade.transactionID , "close ", trade.openClose )

        #  2.1     suche die passende Open-Order
        openTransactionID = selectOpenTransactionID ( dbCursor, trade )
        # 23.06.23 - Wenn die Positionnicht drin ist, aufhören 
        if openTransactionID == None:
            print (f"+++ 282- keine Offene Position vorhanden, auch OK Open Transaction {openTransactionID} " )
            return 
        else:
            print (f"+++ 284 - Open Transaction {openTransactionID} " )
        openStatement = selectStatement ( dbCursor, openTransactionID)
        openTrade = selectTrade ( dbCursor, openTransactionID)
        # opOpenTrade = opSelectTrade (dbCursor, openTransactionID)

        #  2.3     Trage Trade in Closed ein
        cpInsertClosedTrade ( dbCursor, openStatement, statement, openTrade, trade ) #  opOpenTrade )

        # 2.3 Erzeuge für diesen Trade eien entsprechende Steuerdatensatz  
        # txInsertCloseTaxTrade ( dbCursor, openStatement, statement, openTrade, trade, quantity  ) # Close
        #
        
        #  2.4     Update die Quantity im Depot, falls 0 lösche den Eintrag im Depot 
        # %s%s%s Klären, ob das stimmt  
        if (  trade.quantity >= -openTrade.quantity ):  # Schaen, ob es noch mehr zu tun gibt  
            opDeleteTrade ( dbCursor, openTrade)
        else:
            opUpdateTrade ( dbCursor, openTrade, openStatement, statement, trade )        
        
        return trade.quantity  - openTrade.quantity  # %s%s%s noch klären, ob das stimmt 

    else :
        print (trade.openClose , " ist weder Close noch Open, da ist was faul")
        exit () 



#--------- Eintragen in das Depot -----------
# 1,1 - Open-Order - in das Depot eintragen (incl. Quantity)  
def opInsertOpenTrade ( dbCursor, statement, trade, lastTrade ): # lastTradeTime, lastTransactionID):
    try:
        opCombo = calculateCombo ( dbCursor , statement, trade, lastTrade )
        opAmount = statement.amount
    except ValueError:
        print (f"+++ 307 - Fehler bei Combo-Berechnung: Trade:{trade}, LastTrade:{lastTrade},  opAmount:{opAmount}")
        exit()
        
    # Einzelpreis = Gesamtpreis/trade.quantity 
    daysToExpiration= calculateDaysToExpiration( trade ) 
    
    sql = "INSERT INTO openPositions (symbol, description, conid, amount, quantity, transactionID, buySell, assetCategory, combo , daysToExpiration) "
    sql += "Values ( %s, %s, %s, %s, %s, %s, %s, %s, %s, %s )"
    werte = ( trade.symbol, trade.description, trade.conid, opAmount , trade.quantity, trade.transactionID, trade.buySell, trade.assetCategory, opCombo, daysToExpiration)
    dbCursor.execute ( sql, werte )
    dbConn.commit() # Wirklich eintragen 

    str = f"Open-Trade {trade.description} mit Gesamtpreis {opAmount} mit Anzahl: {trade.quantity} eingetragen , Combo: {opCombo}"
    print ( str )
    updateStatementOpInfo ( dbCursor, statement, str  ) 


def cpInsertClosedTrade ( bCursor, openStatement, closeStatement, openTrade, closeTrade  ) :  

    daysToExpiration= calculateDaysToExpiration( openTrade )   
    daysInTrade = calculateDaysInTrade ( openTrade, closeTrade ) 

    openAmount  = openStatement.amount
    closeAmount = closeStatement.amount

    openQuantity  = openTrade.quantity 
    closeQuantity = closeTrade.quantity        

    # Der Einzelpreis beim öffnen 
    closeResult = (openAmount/closeQuantity)*closeQuantity + closeAmount  
    
    comment = (f"{openTrade.assetCategory}  {openTrade.buySell} --> {closeTrade.buySell} {openAmount} {closeAmount} Ergebnis: {closeResult}")

    sql = "INSERT INTO closedPositions (transactionID, symbol, description, conid, assetCategory, " 
    sql += "openTransactionID, openBuySell, openDate, openAmount, daysToExpiration, openQuantity, "
    sql += "closeDate, daysInTrade, closeAmount, closeQuantity, closeBuySell, closeResult, comment ) "
    sql += "Values ( %s, %s, %s, %s, %s, "
    sql += "         %s, %s, %s, %s, %s, %s, "
    sql += "         %s, %s, %s, %s, %s, %s, %s)"
    werte = ( closeTrade.transactionID, closeTrade.symbol, closeTrade.description, closeTrade.conid,  closeTrade.assetCategory, \
            openTrade.transactionID, openTrade.buySell, openTrade.tradeDate, openAmount, daysToExpiration, openQuantity,   \
            closeTrade.tradeDate, daysInTrade, closeAmount , closeQuantity, closeTrade.buySell, closeResult, comment )
    dbCursor.execute ( sql, werte )
    dbConn.commit() # Wirklich eintragen 

    str = f"Close-Trade {closeTrade.description} mit Gesamtpreis {closeAmount} mit Anzahl: {closeTrade.quantity} eingetragen "
    print (str)
    updateStatementOpInfo ( dbCursor, statement, str  ) 


# ------------- TAX ------------------------------------------

def txIsOptOpenTrade ( trade ):
    if trade.openClose == "Open" and trade.buySell == "SELL" and trade.assetCategory == "OPT" :
        return True
    else:
        return False

def txTryInsertTaxStatement ( dbCursor, statement, trade, datensatz) :
    # Bei einem Sell/Verkauf wird nur Fall einer Option eine Steuerdatensatz erzeugt
    # die Vereinnahme Prämie ist ein steuerlicher Gewinn 
    #
    # 07.07. Neuer Beschluss:... jedes Statment kommt in die Tax Tabelle, damit alles dokumentiert ist 

    info = f"Category: {trade.assetCategory} OpenClose: {trade.openClose}  buySell:  {trade.buySell} "
    print ( f"++ 333 - tx Insert Tax Statment {info}" )

    # if txIsOptOpenTrade ( trade ) :
    #    # Vereinnahmete Prämie ist beim Eröffnen steuerlich relevant
    #   txInsertTaxStatement ( dbCursor, statement, trade , datensatz)
    #  return 
    
    #if ( trade.openClose == "Close" ):
    #   # alle Close-Fälle verursachen einen steuerlichen Datensatz 
    #  txInsertTaxStatement ( dbCursor, statement, trade , datensatz )

    # 07.07.23 BG Jedes Statment, auch bei 0€ soll in die Steuertabelle 
    txInsertTaxStatement ( dbCursor, statement, trade , datensatz )     

def txInsertTaxStatement ( dbCursor, statement, trade, datensatz ) :
    # Datensatz: nur zum Testen, dass ich nachvollziehen kann, was passiert 
    # Bei einem verkauften Call ist der steuerliche Gewinn die Prämie  

    if trade.openClose == "Open":
        print (f"+++ TX Insert Im Zustand Open, Amount ist {statement.amount }  TradeOPen: {trade.openClose}")
        taxFiFoResult = statement.amount 
    else:
        print (f"+++ TX Insert Im Zustand Close, Amount ist {statement.amount }")
        taxFiFoResult = taxCalculateFiFoResult ( dbCursor, statement, trade )
    
    txYear = statement.datum.year

    # 06.07.23 BG Umgestellt auf Base-Amount 
    # 06.07.23 Bg ergänzt zur besseren Lesbarkeit der Tabelle: underlyingSymbol, activityDescription
    # 11.07.23 BG Feld - fxRateToBase + action weiter gereicht 
    comment = f"in: txInsertTax Statement {trade.openClose} {trade.description} mit Gesamtpreis {statement.amount} mit Anzahl: {trade.quantity} eingetragen FiFo {taxFiFoResult} "
    sql = "INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, "
    sql += "openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, " 
    sql += "taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) "
    sql += "Values ( %s, %s, %s, %s, %s, %s, %s, "
    sql += "         %s, %s, %s, %s, %s, %s, %s, %s , %s, "
    sql += "         %s, %s, %s, %s, %s , %s )"
    werte = ( statement.transactionID, trade.symbol, statement.underlyingSymbol, trade.conid,  trade.description, statement.activityDescription, trade.assetCategory, \
            trade.openClose, trade.tradeDate, txYear, trade.buySell, trade.putCall, statement.amount, statement.IBcurrency, \
            statement.balance, trade.fifoPnlRealized, taxFiFoResult, trade.quantity, comment, datensatz, trade.fxRateToBase, trade.action )
    print ( sql ) 
    dbCursor.execute ( sql, werte )
    dbConn.commit() # Wirklich eintragen 
    print (comment)
    updateStatementTxInfo ( dbCursor, statement, f"+ 530 - Tx eingtragen Abschluss: {taxFiFoResult} Laut fifoPnlRealized  {trade.fifoPnlRealized} Erfolg oder nicht?    " ) 
    txUpdateTaxStatement ( dbCursor , statement, trade, statement.transactionID, trade.fifoPnlRealized, taxFiFoResult) # Hier wird die Steuer zugeordnet 

# ---- TAX -  Hiwr ist die Steuerlogik , was wo hin kommt 
def txUpdateTaxStatement ( dbCursor , statement, trade, transactionID, fifoPnlRealized, taxFiFoResult ): # Hier wird die Steuer zugeordnet 

    info = f"Category: {trade.assetCategory} OpenClose: {trade.openClose}  buySell:  {trade.buySell} "
    print ( "+++ txUpadte Tax Statment" + info )
    sqlField = None

    if txIsOptOpenTrade ( trade ):  # STO = Sell to Open Stillhalter !! Steuerlich relevant 
        # Eine Verkauf eine Stillhalter-Position erzeugt eine Gewinn 
        sqlField = f"taxAmountStillhalterGewinn = {taxFiFoResult}" 
        
    elif trade.openClose == "Open" :
        return # In allen anderen Fällen bei Open gibt es steuerlich nix zu tun 
    
    # Wir sind im Zustand: CLOSE#
    # 11.07.23 Bg wir werden schlauer 
    elif trade.assetCategory == "OPT":  
        # 11.07. BG Ich habe das Feld:. . fifoPnLRealized, da sagt mir, ob der Trade erfolgreich 
        if trade.quantity > 0: # Ich kaufe eine Stillhalter-Option zurück. 
            if fifoPnlRealized > 0.0 : # 11.07. BG Trade war erfolkgreich 
                sqlField = f"taxAmountStillhalterGewinn = {taxFiFoResult}" 
            else: 
                sqlField = f"taxAmountStillhalterverlust = {taxFiFoResult}" 
        # eine Long-Position wurde verkauft        STC = Sell To Close  
        elif fifoPnlRealized > 0.0 : # Trade war erfolgreich eine Long-Position wurde verkauft 
            sqlField = f"taxAmountTerminGewinn = {taxFiFoResult}" 
        else: 
            sqlField = f"taxAmountTerminVerlust = {taxFiFoResult}" 

    # 11.07 - Was muss ich bei AKtien machen         
    elif trade.assetCategory == "STK":  
        if taxFiFoResult > 0.0 :
            sqlField = f"taxAmountAktienGewinn = {taxFiFoResult}" 
        else: 
            sqlField = f"taxAmountAktienverlust = {taxFiFoResult}" 

    if sqlField != None:
        sql = f"UPDATE taxStatements SET {sqlField} WHERE transactionID = {transactionID} "
        print ( f"{sql}" ) 
        dbCursor.execute ( sql)  
        dbConn.commit() # Wirklich eintragen 

def taxCalculateFiFoResult ( dbCursor, statement, trade ): 
    # Ausgangsbasis: zu einem abgeschlossen Trade kann es mehr oder weniger offene Positionen geben
    # diese haben jeweils unterschiedliche Einkaufs/Verkaufspreise . Das muss ich entsprechend berücksichtigen.
    # So richtig gut klappt es auf einzelne Stücke, d.h. ich rechne für jedes Stück den Einkaufspreis 

    # Vorgehensweise: gehe die openPositions und addiere Schrittweise den Gewinn  
    #      
    
    
    
    if trade.assetCategory == "STK":
        # 11.07.23 Aktien richtig behandelt 
        return trade.fifoPnlRealized 
    elif trade.assetCategory == "OPT" and trade.action == "STC":
        # 13.07.23 BG / FR - Exit einer Long-Option 
        return trade.fifoPnlRealized
    else:
        return statement.amount

#********************************* BG 05.07. ---  erst mal abgeklemmt --------
    opAnzahl = opGetPositionsCount (trade.conid)
    print (f" ---- Calculate Result - Anzahl Positionen >{opAnzahl}<")
    if opAnzahl == 0:
        # Keine offenen Positionen vorhanden , nehmen wir die IB-Angabe
        if ( statement.amount) == 0 :
            print ("+++++++++++ Houston - wir haben ein Problem, keinen Gewinn mit der Position")
            return ( 0.0) 
        else:
            print (f"Bei {statement.description} gibt es keine offenen Position, Amount {statement.amount} aus Statment verwendet")
            return ( statement.amount )

    quantity =  abs(trade.quantity) # wir wollen die Absolute  
    amountSingle = statement.amount / quantity #
    print ( f"fiFo: Ausgangsbasis Coinid {trade.conid}  Gesamtpreis {statement.amount} Einzelpreis {amountSingle}")  
    
    fifoResult = Decimal (0.0) # Ausgangsbasis

    sql = f"SELECT * FROM openPositions WHERE conid = {trade.conid} ORDER BY transactionID"
    print ( sql )
    dbCursor.execute ( sql) 
    for op in dbCursor.fetchall ():
        # Alle offenen Positionen abarbeiten, bis wir die Quantity abgearbeit haben 
        opQuantity = op.quantity 
        opAmountSingle = op.opAmount / abs(opQuantity)
        print (f"Start: AnzahlGesamt: {trade.quantity} Open-Gesamt: {op.opAmount} Close-Gesamt: {statement.amount}")
        for i in range (abs(opQuantity)):
            singleResult = amountSingle + opAmountSingle 
            fifoResult += singleResult
            quantity -= 1 # Einen haben wir abgearbeitet 
            print (f"AnzahlGesamt: {trade.quantity} Noch zu berechnen: {quantity} Open: {opAmountSingle} Close: {amountSingle} EinzelResult {singleResult} Bisherige Summe {fifoResult}")
            if quantity == 0 :
                print (f"IB in $: {trade.fifoPnlRealized} Deutsche Steuer Ergebnis in € {fifoResult}")
                return fifoResult 


# --------- Start des Programms --------------------------

#Datenbank öffnen 
#Datenbank öffnen 
# Verbindung zur Access-Datenbank herstellen
# Verbindung zur Datenbank herstellen
dbConn = pymysql.Connect(
    host='localhost',
    port=3306,
    user='root',
    password='root',
    db='IB',
    charset='utf8'
)

dbCursor = dbConn.cursor()

#alle Daten löschen 
print ("Delete OP")
sql= "DELETE FROM openPositions"
dbCursor.execute (sql)

print ("Delete CP")
sql= "DELETE FROM closedPositions"
dbCursor.execute (sql)

print ("Delete TS")
sql= "DELETE FROM taxStatements"
dbCursor.execute (sql)
dbConn.commit()

"""

# Testen des Programms
# Zeile 495 
i = 0
datensatz = 0 
anfang = 1 #  Hier kann ich auch sagen: ... starte erst bei Datensatz x 
max = 2000

#sql = "SELECT * FROM statements, trades WHERE statement.TransactionID = orders.TransactionID"
# 17.06. Versuch, mit einem Join das zu machen, ist gescheitert, stört aber nicht, so habe ich zwei einzelne Select gemacht 
# sql += " AND underlyingSymbol = 'NVDA' "0 
# sql += " AND description = 'NVDA 20JAN23 177.5 C' "
# sql += " AND description = 'NVIDIA CORP' " 
# sql = "SELECT * FROM statements WHERE tradeID > 0 ORDER BY transactionID, levelOfDetails"

desc = "FIRST SOLAR INC"
desc = "NVIDIA CORP"
#desc = "NVDA 17FEB23 177.5 P"
desc = "NVDA 20Jan23 177.5 C"

sql = "SELECT * FROM statements WHERE tradeID = tradeID "
#sql += f" AND description = '{desc}' " # Versuch, die Aktien zu klären 
sql += " ORDER BY transactionID, levelOfDetail"


print (f"Start der Eintragung {sql}"  )
dbCursor.execute ( sql) 

#lastTradeTime = " " # Letzten Tradetime merken
#lastTransactionID = 0
lastTrade = None

baseCurrency = "BaseCurrency"

print ( f"Ausgangslage: Test mit {desc} in der Range {anfang} und {max}")

"""
# Out:
# Delete OP
# Delete CP
# Delete TS
# '\n\n# Testen des Programms\n# Zeile 495 \ni = 0\ndatensatz = 0 \nanfang = 1 #  Hier kann ich auch sagen: ... starte erst bei Datensatz x \nmax = 2000\n\n#sql = "SELECT * FROM statements, trades WHERE statement.TransactionID = orders.TransactionID"\n# 17.06. Versuch, mit einem Join das zu machen, ist gescheitert, stört aber nicht, so habe ich zwei einzelne Select gemacht \n# sql += " AND underlyingSymbol = \'NVDA\' "0 \n# sql += " AND description = \'NVDA 20JAN23 177.5 C\' "\n# sql += " AND description = \'NVIDIA CORP\' " \n# sql = "SELECT * FROM statements WHERE tradeID > 0 ORDER BY transactionID, levelOfDetails"\n\ndesc = "FIRST SOLAR INC"\ndesc = "NVIDIA CORP"\n#desc = "NVDA 17FEB23 177.5 P"\ndesc = "NVDA 20Jan23 177.5 C"\n\nsql = "SELECT * FROM statements WHERE tradeID = tradeID "\n#sql += f" AND description = \'{desc}\' " # Versuch, die Aktien zu klären \nsql += " ORDER BY transactionID, levelOfDetail"\n\n\nprint (f"Start der Eintragung {sql}"  )\ndbCursor.execute ( sql) \n\n#lastTradeTime = " " # Letzten Tradetime merken\n#lastTransactionID = 0\nlastTrade = None\n\nbaseCurrency = "BaseCurrency"\n\nprint ( f"Ausgangslage: Test mit {desc} in der Range {anfang} und {max}")\n\n'

# %%
datensatz = 0 
anfang = 1
max = 30
lastTrade = None
baseCurrency = "BaseCurrency"

dbCursor.execute("SELECT * FROM statements") 
statements = dbCursor.fetchall()
statements = pd.DataFrame(statements, columns=[i[0] for i in dbCursor.description])

for i,statement in statements.iterrows():

    # Nur zu Testzwecken, um nur einige Datensätze durchzugehen  
    i += 1
    datensatz = i 
    print (" ")
    print (f"+ 493 - ++++++++++ Datensatz {i} ++ID: {statement.id} ++++  {statement.activityDescription} +++++ Max = {max}++++ Start {anfang}+++++")
    if (i > max): 
        print (f"+ 495 - +++++++Abbruch wegen max {max}")
        break # Testweise vorher aufhören

    if (i < anfang ):
        print (f"+ 497 - Überspringe Datensatz {i} (zum Testen) Anfang {anfang}")
        continue   # 02.07. die ersten Datensätze überspringen 

    # Noch zu bearbeiten 
    #qifInsertTransaction ( statement) # 09.07.2023 Money mit eingeführt 
    
    trade = selectTrade ( dbCursor, statement.transactionID ) 
    
    print (f"+++ 496 - Statement {statement}")
    
    # 05.07.23 BG umgestellt auf "levelOfDetail" 
    if ( statement.levelOfDetail != baseCurrency ):
        # 06.07.23 BG Aus dem zweiten Datensatz ergänze ich den amount / currency 
        #updateTxAmountCurrency ( dbCursor, statement )
        #print (f"+ - 560 Update Currency:  {statement.IBcurrency} Amount: {statement.amount} Balance: {statement.balance} Beschreibung: {statement.activityDescription}")
        continue 

    # 28.06.23 BG Klären, warum es keinen Trade zu dieser Transaktion gibt 
    if trade is None:
        str = f"+ - 500 - Keinen Trade gefunden für {statement.activityDescription} ID: {statement.transactionID}"
        print (str)
        updateStatementTxInfo ( dbCursor, statement, str ) 
        continue 
    else :
        print (f"+++ 505 - Trade {trade} zu Statement gefunden ")
    
    if trade is not None:
        # 01.07.2023 - Wenn ich mitten drin starte, Skippen, wenn ich keien offenen Positionen habe 
        anzahl = opGetPositionsCount (dbCursor, trade.conid) # Klären, ob wir genug Quantity für diese conid haben 
        print (f"+ 517 opGetPositionsCount (trade.conid) > Trade Quantity = {trade.quantity}  Anzahl Offene Positionen: {anzahl} - Welcher Typ: ? {trade.openClose}  ")
        # 02.07. Quantity muss abs()  sein 
    
        ################## !!!!!!!!!!!!!!!!!!!!!
        # 06.07.23 BG - Aktuell wollen wir nur Steuer haben - deshalb achten wir zur Zeit nicht, ob es in den offenen Positionen ist  
        if (trade.openClose == "Close"): # and (abs(trade.quantity) > anzahl):
            anzahl = "Unknown"
            str = f"+ - 508 - Close + Anzahl > 0 , Anzahl {trade.quantity} , Denncohweiter Frage: ? nicht in den offenen Positionen {anzahl} enthalten" 
            print (str)
            # Wir teilen es zumidnest mit, machen aber weiter 
        #    updateStatementTxInfo ( dbCursor, statement, str )
        #    continue

        print ("# - 513 - Insert Tax Statment ")
        # Klären, ob es einen Tax-Datensatz geben soll, wenn ja, wird er eingetragen 
        txTryInsertTaxStatement ( dbCursor, statement, trade , datensatz ) # Jedes Statement gibt einen Steuerdatensatz, weil der ist correct

        # Der Teil für IB-Info 
        updateOpenPositions ( dbCursor , statement, trade, lastTrade ) # OLD: lastTradeTime, lastTransactionID )
        lastTrade = trade.copy() 
 

print (f" FERTIG mit {datensatz} Datensätzen" )
# Out:
#
# + 493 - ++++++++++ Datensatz 1 ++ID: 515 ++++  Electronic Fund Transfer +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 1934263195
# +++ 187 - selectTrade -Kein Trade gefunden für TransaktionsID: 1934263195
# +++ 496 - Statement id                                                                   515
# transactionID                                                 1934263195
# accountID                                                      U12047171
# datum                                                2023-06-14 00:00:00
# amount                                                          100.0000
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                         100.0000
# description
# activityCode                                                         DEP
# activityDescription                             Electronic Fund Transfer
# symbol
# underlyingSymbol
# txInfo                 + - 500 - Keinen Trade gefunden für Electronic...
# opInfo                                                              None
# Name: 0, dtype: object
# + - 500 - Keinen Trade gefunden für Electronic Fund Transfer ID: 1934263195
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ - 500 - Keinen Trade gefunden für Electronic Fund Transfer ID: 1934263195'     WHERE transactionID = 1934263195 AND  levelOfDetail = 'BaseCurrency'
#
# + 493 - ++++++++++ Datensatz 2 ++ID: 516 ++++  Electronic Fund Transfer +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 1944519765
# +++ 187 - selectTrade -Kein Trade gefunden für TransaktionsID: 1944519765
# +++ 496 - Statement id                                                                   516
# transactionID                                                 1944519765
# accountID                                                      U12047171
# datum                                                2023-06-19 00:00:00
# amount                                                        25000.0000
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25100.0000
# description
# activityCode                                                         DEP
# activityDescription                             Electronic Fund Transfer
# symbol
# underlyingSymbol
# txInfo                 + - 500 - Keinen Trade gefunden für Electronic...
# opInfo                                                              None
# Name: 1, dtype: object
# + - 500 - Keinen Trade gefunden für Electronic Fund Transfer ID: 1944519765
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ - 500 - Keinen Trade gefunden für Electronic Fund Transfer ID: 1944519765'     WHERE transactionID = 1944519765 AND  levelOfDetail = 'BaseCurrency'
#
# + 493 - ++++++++++ Datensatz 3 ++ID: 517 ++++  Z******60:GLOBAL SNAPSHOT FOR JUN 2023 +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 1975082121
# +++ 187 - selectTrade -Kein Trade gefunden für TransaktionsID: 1975082121
# +++ 496 - Statement id                                                                   517
# transactionID                                                 1975082121
# accountID                                                      U12047171
# datum                                                2023-07-03 00:00:00
# amount                                                           -0.0300
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25099.9700
# description
# activityCode                                                        OFEE
# activityDescription               Z******60:GLOBAL SNAPSHOT FOR JUN 2023
# symbol
# underlyingSymbol
# txInfo                 + - 500 - Keinen Trade gefunden für Z******60:...
# opInfo                                                              None
# Name: 2, dtype: object
# + - 500 - Keinen Trade gefunden für Z******60:GLOBAL SNAPSHOT FOR JUN 2023 ID: 1975082121
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ - 500 - Keinen Trade gefunden für Z******60:GLOBAL SNAPSHOT FOR JUN 2023 ID: 1975082121'     WHERE transactionID = 1975082121 AND  levelOfDetail = 'BaseCurrency'
#
# + 493 - ++++++++++ Datensatz 4 ++ID: 518 ++++  Z******60:GLOBAL SNAPSHOT FOR JUN 2023 +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 1975082125
# +++ 187 - selectTrade -Kein Trade gefunden für TransaktionsID: 1975082125
# +++ 496 - Statement id                                                                   518
# transactionID                                                 1975082125
# accountID                                                      U12047171
# datum                                                2023-07-03 00:00:00
# amount                                                            0.0300
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25100.0000
# description
# activityCode                                                        OFEE
# activityDescription               Z******60:GLOBAL SNAPSHOT FOR JUN 2023
# symbol
# underlyingSymbol
# txInfo                 + - 500 - Keinen Trade gefunden für Z******60:...
# opInfo                                                              None
# Name: 3, dtype: object
# + - 500 - Keinen Trade gefunden für Z******60:GLOBAL SNAPSHOT FOR JUN 2023 ID: 1975082125
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ - 500 - Keinen Trade gefunden für Z******60:GLOBAL SNAPSHOT FOR JUN 2023 ID: 1975082125'     WHERE transactionID = 1975082125 AND  levelOfDetail = 'BaseCurrency'
#
# + 493 - ++++++++++ Datensatz 5 ++ID: 519 ++++  VAT z******60:Global Snapshot +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 1975133492
# +++ 187 - selectTrade -Kein Trade gefunden für TransaktionsID: 1975133492
# +++ 496 - Statement id                                                                   519
# transactionID                                                 1975133492
# accountID                                                      U12047171
# datum                                                2023-07-03 00:00:00
# amount                                                           -0.0057
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25099.9900
# description
# activityCode                                                        STAX
# activityDescription                        VAT z******60:Global Snapshot
# symbol
# underlyingSymbol
# txInfo                 + - 500 - Keinen Trade gefunden für VAT z*****...
# opInfo                                                              None
# Name: 4, dtype: object
# + - 500 - Keinen Trade gefunden für VAT z******60:Global Snapshot ID: 1975133492
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ - 500 - Keinen Trade gefunden für VAT z******60:Global Snapshot ID: 1975133492'     WHERE transactionID = 1975133492 AND  levelOfDetail = 'BaseCurrency'
#
# + 493 - ++++++++++ Datensatz 6 ++ID: 520 ++++  Z******60:OPRA NP L1 FOR JUL 2023 +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 1979783621
# +++ 187 - selectTrade -Kein Trade gefunden für TransaktionsID: 1979783621
# +++ 496 - Statement id                                                                   520
# transactionID                                                 1979783621
# accountID                                                      U12047171
# datum                                                2023-07-05 00:00:00
# amount                                                           -1.3700
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25098.6200
# description
# activityCode                                                        OFEE
# activityDescription                    Z******60:OPRA NP L1 FOR JUL 2023
# symbol
# underlyingSymbol
# txInfo                 + - 500 - Keinen Trade gefunden für Z******60:...
# opInfo                                                              None
# Name: 5, dtype: object
# + - 500 - Keinen Trade gefunden für Z******60:OPRA NP L1 FOR JUL 2023 ID: 1979783621
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ - 500 - Keinen Trade gefunden für Z******60:OPRA NP L1 FOR JUL 2023 ID: 1979783621'     WHERE transactionID = 1979783621 AND  levelOfDetail = 'BaseCurrency'
#
# + 493 - ++++++++++ Datensatz 7 ++ID: 521 ++++  VAT z******60:OPRA NP L1 +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 1979784589
# +++ 187 - selectTrade -Kein Trade gefunden für TransaktionsID: 1979784589
# +++ 496 - Statement id                                                                   521
# transactionID                                                 1979784589
# accountID                                                      U12047171
# datum                                                2023-07-05 00:00:00
# amount                                                           -0.2603
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25098.3600
# description
# activityCode                                                        STAX
# activityDescription                             VAT z******60:OPRA NP L1
# symbol
# underlyingSymbol
# txInfo                 + - 500 - Keinen Trade gefunden für VAT z*****...
# opInfo                                                              None
# Name: 6, dtype: object
# + - 500 - Keinen Trade gefunden für VAT z******60:OPRA NP L1 ID: 1979784589
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ - 500 - Keinen Trade gefunden für VAT z******60:OPRA NP L1 ID: 1979784589'     WHERE transactionID = 1979784589 AND  levelOfDetail = 'BaseCurrency'
#
# + 493 - ++++++++++ Datensatz 8 ++ID: 522 ++++  Buy 1 SPXW 17JUL23 4375 P  +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2003659536
# +++ 496 - Statement id                                                                   522
# transactionID                                                 2003659536
# accountID                                                      U12047171
# datum                                                2023-07-17 00:00:00
# amount                                                           -5.8299
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25092.5300
# description                                          SPXW 17JUL23 4375 P
# activityCode                                                         BUY
# activityDescription                           Buy 1 SPXW 17JUL23 4375 P
# symbol                                             SPXW  230717P04375000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: -5.8299 Laut ...
# opInfo                 Open-Trade SPXW 17JUL23 4375 P mit Gesamtpreis...
# Name: 7, dtype: object
# +++ 505 - Trade transactionID                  2003659536
# accountID                       U12047171
# tradeID                         573887798
# description           SPXW 17JUL23 4375 P
# IBCurrency                            USD
# conid                           635900144
# putCall                                 P
# tradePrice                         0.0500
# tradeDate             2023-07-17 00:00:00
# IBDateTime            2023-07-17 09:58:35
# strike                               4375
# expiryDate            2023-07-17 00:00:00
# action                                BTO
# notes
# openClose                            Open
# quantity                                1
# buySell                               BUY
# symbol              SPXW  230717P04375000
# underlyingSymbol                      SPX
# symbolSort          SPX P - 20230717 4375
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                      0.00
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.55
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 635900144
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 635900144 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = 1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ? Open
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: OPT OpenClose: Open  buySell:  BUY
# +++ TX Insert Im Zustand Open, Amount ist -5.8299  TradeOPen: Open
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement Open SPXW 17JUL23 4375 P mit Gesamtpreis -5.8299 mit Anzahl: 1 eingetragen FiFo -5.8299
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: -5.8299 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2003659536 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: OPT OpenClose: Open  buySell:  BUY
#
# + 493 - ++++++++++ Datensatz 9 ++ID: 523 ++++  Net Amount in Base from Forex Trade: -5 EUR.USD +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2003707757
# +++ 496 - Statement id                                                                   523
# transactionID                                                 2003707757
# accountID                                                      U12047171
# datum                                                2023-07-17 00:00:00
# amount                                                           -1.7870
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25090.7500
# description                                                      EUR.USD
# activityCode                                                       FOREX
# activityDescription      Net Amount in Base from Forex Trade: -5 EUR.USD
# symbol                                                           EUR.USD
# underlyingSymbol
# txInfo                 + 530 - Tx eingtragen Abschluss: -1.7870 Laut ...
# opInfo                                                              None
# Name: 8, dtype: object
# +++ 505 - Trade transactionID                2003707757
# accountID                     U12047171
# tradeID                       573905712
# description                     EUR.USD
# IBCurrency                          USD
# conid                          12087792
# putCall
# tradePrice                       1.1225
# tradeDate           2023-07-17 00:00:00
# IBDateTime          2023-07-17 10:12:44
# strike
# expiryDate                         None
# action                              STC
# notes
# openClose
# quantity                             -5
# buySell                            SELL
# symbol                          EUR.USD
# underlyingSymbol
# symbolSort                          -
# assetCategory                      CASH
# multiplier                            1
# transactionType               ExchTrade
# cost                               0.00
# fifoPnlRealized                    0.00
# capitalGainsPnl                    0.00
# fxPnl                              0.00
# fxRateToBase                       0.00
# ibCommission                      -1.78
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 12087792
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 12087792 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = -5  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ?
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: CASH OpenClose:   buySell:  SELL
# +++ TX Insert Im Zustand Close, Amount ist -1.7870
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement  EUR.USD mit Gesamtpreis -1.7870 mit Anzahl: -5 eingetragen FiFo -1.7870
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: -1.7870 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2003707757 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: CASH OpenClose:   buySell:  SELL
#
# + 493 - ++++++++++ Datensatz 10 ++ID: 524 ++++  Net Amount in Base from Forex Trade: -0.8385 EUR.USD +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2010856489
# +++ 496 - Statement id                                                                   524
# transactionID                                                 2010856489
# accountID                                                      U12047171
# datum                                                2023-07-20 00:00:00
# amount                                                            0.0054
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25090.7500
# description                                                      EUR.USD
# activityCode                                                       FOREX
# activityDescription    Net Amount in Base from Forex Trade: -0.8385 E...
# symbol                                                           EUR.USD
# underlyingSymbol
# txInfo                 + 530 - Tx eingtragen Abschluss: 0.0054 Laut f...
# opInfo                                                              None
# Name: 9, dtype: object
# +++ 505 - Trade transactionID                2010856489
# accountID                     U12047171
# tradeID                       575691402
# description                     EUR.USD
# IBCurrency                          USD
# conid                          12087792
# putCall
# tradePrice                       1.1202
# tradeDate           2023-07-20 00:00:00
# IBDateTime          2023-07-19 20:15:23
# strike
# expiryDate                         None
# action                              STC
# notes
# openClose
# quantity                             -1
# buySell                            SELL
# symbol                          EUR.USD
# underlyingSymbol
# symbolSort                          -
# assetCategory                      CASH
# multiplier                            1
# transactionType               ExchTrade
# cost                               0.00
# fifoPnlRealized                    0.00
# capitalGainsPnl                    0.00
# fxPnl                              0.00
# fxRateToBase                       0.00
# ibCommission                       0.00
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 12087792
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 12087792 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = -1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ?
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: CASH OpenClose:   buySell:  SELL
# +++ TX Insert Im Zustand Close, Amount ist 0.0054
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement  EUR.USD mit Gesamtpreis 0.0054 mit Anzahl: -1 eingetragen FiFo 0.0054
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: 0.0054 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2010856489 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: CASH OpenClose:   buySell:  SELL
#
# + 493 - ++++++++++ Datensatz 11 ++ID: 525 ++++  Sell -1 SPXW 24JUL23 4530 P  +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2018886378
# +++ 496 - Statement id                                                                   525
# transactionID                                                 2018886378
# accountID                                                      U12047171
# datum                                                2023-07-24 00:00:00
# amount                                                          102.4534
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25193.2100
# description                                          SPXW 24JUL23 4530 P
# activityCode                                                        SELL
# activityDescription                         Sell -1 SPXW 24JUL23 4530 P
# symbol                                             SPXW  230724P04530000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: 102.4534 Laut...
# opInfo                 Open-Trade SPXW 24JUL23 4530 P mit Gesamtpreis...
# Name: 10, dtype: object
# +++ 505 - Trade transactionID                  2018886378
# accountID                       U12047171
# tradeID                         577470425
# description           SPXW 24JUL23 4530 P
# IBCurrency                            USD
# conid                           640373997
# putCall                                 P
# tradePrice                         1.1500
# tradeDate             2023-07-24 00:00:00
# IBDateTime            2023-07-24 09:37:13
# strike                               4530
# expiryDate            2023-07-24 00:00:00
# action                                STO
# notes
# openClose                            Open
# quantity                               -1
# buySell                              SELL
# symbol              SPXW  230724P04530000
# underlyingSymbol                      SPX
# symbolSort          SPX P - 20230724 4530
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                      0.00
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.64
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 640373997
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 640373997 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = -1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ? Open
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: OPT OpenClose: Open  buySell:  SELL
# +++ TX Insert Im Zustand Open, Amount ist 102.4534  TradeOPen: Open
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement Open SPXW 24JUL23 4530 P mit Gesamtpreis 102.4534 mit Anzahl: -1 eingetragen FiFo 102.4534
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: 102.4534 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2018886378 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: OPT OpenClose: Open  buySell:  SELL
# UPDATE taxStatements SET taxAmountStillhalterGewinn = 102.4534 WHERE transactionID = 2018886378
#
# + 493 - ++++++++++ Datensatz 12 ++ID: 526 ++++  Buy 1 SPXW 24JUL23 4480 P  +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2018886553
# +++ 496 - Statement id                                                                   526
# transactionID                                                 2018886553
# accountID                                                      U12047171
# datum                                                2023-07-24 00:00:00
# amount                                                          -10.4403
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25182.7700
# description                                          SPXW 24JUL23 4480 P
# activityCode                                                         BUY
# activityDescription                           Buy 1 SPXW 24JUL23 4480 P
# symbol                                             SPXW  230724P04480000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: -10.4403 Laut...
# opInfo                 Open-Trade SPXW 24JUL23 4480 P mit Gesamtpreis...
# Name: 11, dtype: object
# +++ 505 - Trade transactionID                  2018886553
# accountID                       U12047171
# tradeID                         577470442
# description           SPXW 24JUL23 4480 P
# IBCurrency                            USD
# conid                           639456782
# putCall                                 P
# tradePrice                         0.1000
# tradeDate             2023-07-24 00:00:00
# IBDateTime            2023-07-24 09:37:13
# strike                               4480
# expiryDate            2023-07-24 00:00:00
# action                                BTO
# notes
# openClose                            Open
# quantity                                1
# buySell                               BUY
# symbol              SPXW  230724P04480000
# underlyingSymbol                      SPX
# symbolSort          SPX P - 20230724 4480
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                      0.00
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.55
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 639456782
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 639456782 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = 1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ? Open
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: OPT OpenClose: Open  buySell:  BUY
# +++ TX Insert Im Zustand Open, Amount ist -10.4403  TradeOPen: Open
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement Open SPXW 24JUL23 4480 P mit Gesamtpreis -10.4403 mit Anzahl: 1 eingetragen FiFo -10.4403
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: -10.4403 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2018886553 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: OPT OpenClose: Open  buySell:  BUY
#
# + 493 - ++++++++++ Datensatz 13 ++ID: 527 ++++  Buy 1 SPXW 24JUL23 4625 C  +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2018893327
# +++ 496 - Statement id                                                                   527
# transactionID                                                 2018893327
# accountID                                                      U12047171
# datum                                                2023-07-24 00:00:00
# amount                                                           -5.9213
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25176.8400
# description                                          SPXW 24JUL23 4625 C
# activityCode                                                         BUY
# activityDescription                           Buy 1 SPXW 24JUL23 4625 C
# symbol                                             SPXW  230724C04625000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: -5.9213 Laut ...
# opInfo                 Open-Trade SPXW 24JUL23 4625 C mit Gesamtpreis...
# Name: 12, dtype: object
# +++ 505 - Trade transactionID                  2018893327
# accountID                       U12047171
# tradeID                         577471564
# description           SPXW 24JUL23 4625 C
# IBCurrency                            USD
# conid                           640373914
# putCall                                 C
# tradePrice                         0.0500
# tradeDate             2023-07-24 00:00:00
# IBDateTime            2023-07-24 09:37:30
# strike                               4625
# expiryDate            2023-07-24 00:00:00
# action                                BTO
# notes
# openClose                            Open
# quantity                                1
# buySell                               BUY
# symbol              SPXW  230724C04625000
# underlyingSymbol                      SPX
# symbolSort          SPX C - 20230724 4625
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                      0.00
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.55
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 640373914
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 640373914 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = 1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ? Open
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: OPT OpenClose: Open  buySell:  BUY
# +++ TX Insert Im Zustand Open, Amount ist -5.9213  TradeOPen: Open
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement Open SPXW 24JUL23 4625 C mit Gesamtpreis -5.9213 mit Anzahl: 1 eingetragen FiFo -5.9213
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: -5.9213 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2018893327 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: OPT OpenClose: Open  buySell:  BUY
#
# + 493 - ++++++++++ Datensatz 14 ++ID: 528 ++++  Sell -1 SPXW 24JUL23 4575 C  +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2018895953
# +++ 496 - Statement id                                                                   528
# transactionID                                                 2018895953
# accountID                                                      U12047171
# datum                                                2023-07-24 00:00:00
# amount                                                           93.4154
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25270.2600
# description                                          SPXW 24JUL23 4575 C
# activityCode                                                        SELL
# activityDescription                         Sell -1 SPXW 24JUL23 4575 C
# symbol                                             SPXW  230724C04575000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: 93.4154 Laut ...
# opInfo                 Open-Trade SPXW 24JUL23 4575 C mit Gesamtpreis...
# Name: 13, dtype: object
# +++ 505 - Trade transactionID                  2018895953
# accountID                       U12047171
# tradeID                         577471539
# description           SPXW 24JUL23 4575 C
# IBCurrency                            USD
# conid                           640373883
# putCall                                 C
# tradePrice                         1.0500
# tradeDate             2023-07-24 00:00:00
# IBDateTime            2023-07-24 09:37:30
# strike                               4575
# expiryDate            2023-07-24 00:00:00
# action                                STO
# notes
# openClose                            Open
# quantity                               -1
# buySell                              SELL
# symbol              SPXW  230724C04575000
# underlyingSymbol                      SPX
# symbolSort          SPX C - 20230724 4575
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                      0.00
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.64
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 640373883
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 640373883 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = -1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ? Open
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: OPT OpenClose: Open  buySell:  SELL
# +++ TX Insert Im Zustand Open, Amount ist 93.4154  TradeOPen: Open
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement Open SPXW 24JUL23 4575 C mit Gesamtpreis 93.4154 mit Anzahl: -1 eingetragen FiFo 93.4154
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: 93.4154 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2018895953 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: OPT OpenClose: Open  buySell:  SELL
# UPDATE taxStatements SET taxAmountStillhalterGewinn = 93.4154 WHERE transactionID = 2018895953
#
# + 493 - ++++++++++ Datensatz 15 ++ID: 529 ++++  Buy 1 SPXW 24JUL23 4530 P  +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2018970448
# +++ 496 - Statement id                                                                   529
# transactionID                                                 2018970448
# accountID                                                      U12047171
# datum                                                2023-07-24 00:00:00
# amount                                                         -240.9906
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25029.2700
# description                                          SPXW 24JUL23 4530 P
# activityCode                                                         BUY
# activityDescription                           Buy 1 SPXW 24JUL23 4530 P
# symbol                                             SPXW  230724P04530000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: -240.9906 Lau...
# opInfo                 Close-Trade SPXW 24JUL23 4530 P mit Gesamtprei...
# Name: 14, dtype: object
# +++ 505 - Trade transactionID                  2018970448
# accountID                       U12047171
# tradeID                         577507300
# description           SPXW 24JUL23 4530 P
# IBCurrency                            USD
# conid                           640373997
# putCall                                 P
# tradePrice                         2.6500
# tradeDate             2023-07-24 00:00:00
# IBDateTime            2023-07-24 09:53:51
# strike                               4530
# expiryDate            2023-07-24 00:00:00
# action                                BTC
# notes
# openClose                           Close
# quantity                                1
# buySell                               BUY
# symbol              SPXW  230724P04530000
# underlyingSymbol                      SPX
# symbolSort          SPX P - 20230724 4530
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                   -153.28
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.64
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 640373997
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 640373997 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = 1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ? Close
# + - 508 - Close + Anzahl > 0 , Anzahl 1 , Denncohweiter Frage: ? nicht in den offenen Positionen Unknown enthalten
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: OPT OpenClose: Close  buySell:  BUY
# +++ TX Insert Im Zustand Close, Amount ist -240.9906
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement Close SPXW 24JUL23 4530 P mit Gesamtpreis -240.9906 mit Anzahl: 1 eingetragen FiFo -240.9906
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: -240.9906 Laut fifoPnlRealized  -153.28 Erfolg oder nicht?    '     WHERE transactionID = 2018970448 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: OPT OpenClose: Close  buySell:  BUY
# UPDATE taxStatements SET taxAmountStillhalterverlust = -240.9906 WHERE transactionID = 2018970448
#
# + 493 - ++++++++++ Datensatz 16 ++ID: 530 ++++  Sell -1 SPXW 24JUL23 4545 P  +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2019769701
# +++ 496 - Statement id                                                                   530
# transactionID                                                 2019769701
# accountID                                                      U12047171
# datum                                                2023-07-24 00:00:00
# amount                                                           84.4587
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25113.7300
# description                                          SPXW 24JUL23 4545 P
# activityCode                                                        SELL
# activityDescription                         Sell -1 SPXW 24JUL23 4545 P
# symbol                                             SPXW  230724P04545000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: 84.4587 Laut ...
# opInfo                 Open-Trade SPXW 24JUL23 4545 P mit Gesamtpreis...
# Name: 15, dtype: object
# +++ 505 - Trade transactionID                  2019769701
# accountID                       U12047171
# tradeID                         577778712
# description           SPXW 24JUL23 4545 P
# IBCurrency                            USD
# conid                           641818287
# putCall                                 P
# tradePrice                         0.9500
# tradeDate             2023-07-24 00:00:00
# IBDateTime            2023-07-24 14:48:02
# strike                               4545
# expiryDate            2023-07-24 00:00:00
# action                                STO
# notes
# openClose                            Open
# quantity                               -1
# buySell                              SELL
# symbol              SPXW  230724P04545000
# underlyingSymbol                      SPX
# symbolSort          SPX P - 20230724 4545
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                      0.00
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.55
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 641818287
#    anzahl
# 0       0
# ...
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25186.3100
# description                                          SPXW 25JUL23 4530 P
# activityCode                                                         BUY
# activityDescription                           Buy 1 SPXW 25JUL23 4530 P
# symbol                                             SPXW  230725P04530000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: -5.9260 Laut ...
# opInfo                 Open-Trade SPXW 25JUL23 4530 P mit Gesamtpreis...
# Name: 26, dtype: object
# +++ 505 - Trade transactionID                  2022659999
# accountID                       U12047171
# tradeID                         578432365
# description           SPXW 25JUL23 4530 P
# IBCurrency                            USD
# conid                           640374327
# putCall                                 P
# tradePrice                         0.0500
# tradeDate             2023-07-25 00:00:00
# IBDateTime            2023-07-25 14:48:05
# strike                               4530
# expiryDate            2023-07-25 00:00:00
# action                                BTO
# notes
# openClose                            Open
# quantity                                1
# buySell                               BUY
# symbol              SPXW  230725P04530000
# underlyingSymbol                      SPX
# symbolSort          SPX P - 20230725 4530
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                      0.00
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.55
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 640374327
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 640374327 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = 1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ? Open
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: OPT OpenClose: Open  buySell:  BUY
# +++ TX Insert Im Zustand Open, Amount ist -5.9260  TradeOPen: Open
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement Open SPXW 25JUL23 4530 P mit Gesamtpreis -5.9260 mit Anzahl: 1 eingetragen FiFo -5.9260
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: -5.9260 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2022659999 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: OPT OpenClose: Open  buySell:  BUY
#
# + 493 - ++++++++++ Datensatz 28 ++ID: 542 ++++  Sell -1 SPXW 25JUL23 4570 P  +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2022660117
# +++ 496 - Statement id                                                                   542
# transactionID                                                 2022660117
# accountID                                                      U12047171
# datum                                                2023-07-25 00:00:00
# amount                                                           84.5260
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25270.8300
# description                                          SPXW 25JUL23 4570 P
# activityCode                                                        SELL
# activityDescription                         Sell -1 SPXW 25JUL23 4570 P
# symbol                                             SPXW  230725P04570000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: 84.5260 Laut ...
# opInfo                 Open-Trade SPXW 25JUL23 4570 P mit Gesamtpreis...
# Name: 27, dtype: object
# +++ 505 - Trade transactionID                  2022660117
# accountID                       U12047171
# tradeID                         578432371
# description           SPXW 25JUL23 4570 P
# IBCurrency                            USD
# conid                           640374366
# putCall                                 P
# tradePrice                         0.9500
# tradeDate             2023-07-25 00:00:00
# IBDateTime            2023-07-25 14:48:05
# strike                               4570
# expiryDate            2023-07-25 00:00:00
# action                                STO
# notes
# openClose                            Open
# quantity                               -1
# buySell                              SELL
# symbol              SPXW  230725P04570000
# underlyingSymbol                      SPX
# symbolSort          SPX P - 20230725 4570
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                      0.00
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.55
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 640374366
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 640374366 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = -1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ? Open
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: OPT OpenClose: Open  buySell:  SELL
# +++ TX Insert Im Zustand Open, Amount ist 84.5260  TradeOPen: Open
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement Open SPXW 25JUL23 4570 P mit Gesamtpreis 84.5260 mit Anzahl: -1 eingetragen FiFo 84.5260
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: 84.5260 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2022660117 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: OPT OpenClose: Open  buySell:  SELL
# UPDATE taxStatements SET taxAmountStillhalterGewinn = 84.5260 WHERE transactionID = 2022660117
#
# + 493 - ++++++++++ Datensatz 29 ++ID: 543 ++++  Buy 1 SPXW 25JUL23 4605 C  +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2022675358
# +++ 496 - Statement id                                                                   543
# transactionID                                                 2022675358
# accountID                                                      U12047171
# datum                                                2023-07-25 00:00:00
# amount                                                           -5.9260
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25264.9100
# description                                          SPXW 25JUL23 4605 C
# activityCode                                                         BUY
# activityDescription                           Buy 1 SPXW 25JUL23 4605 C
# symbol                                             SPXW  230725C04605000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: -5.9260 Laut ...
# opInfo                 Open-Trade SPXW 25JUL23 4605 C mit Gesamtpreis...
# Name: 28, dtype: object
# +++ 505 - Trade transactionID                  2022675358
# accountID                       U12047171
# tradeID                         578441093
# description           SPXW 25JUL23 4605 C
# IBCurrency                            USD
# conid                           642242231
# putCall                                 C
# tradePrice                         0.0500
# tradeDate             2023-07-25 00:00:00
# IBDateTime            2023-07-25 14:57:42
# strike                               4605
# expiryDate            2023-07-25 00:00:00
# action                                BTO
# notes
# openClose                            Open
# quantity                                1
# buySell                               BUY
# symbol              SPXW  230725C04605000
# underlyingSymbol                      SPX
# symbolSort          SPX C - 20230725 4605
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                      0.00
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.55
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 642242231
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 642242231 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = 1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ? Open
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: OPT OpenClose: Open  buySell:  BUY
# +++ TX Insert Im Zustand Open, Amount ist -5.9260  TradeOPen: Open
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement Open SPXW 25JUL23 4605 C mit Gesamtpreis -5.9260 mit Anzahl: 1 eingetragen FiFo -5.9260
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: -5.9260 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2022675358 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: OPT OpenClose: Open  buySell:  BUY
#
# + 493 - ++++++++++ Datensatz 30 ++ID: 544 ++++  Sell -1 SPXW 25JUL23 4580 C  +++++ Max = 30++++ Start 1+++++
# +++ 191 - Select Trade SELECT * FROM trades WHERE transactionID = 2022675485
# +++ 496 - Statement id                                                                   544
# transactionID                                                 2022675485
# accountID                                                      U12047171
# datum                                                2023-07-25 00:00:00
# amount                                                          102.5350
# IBcurrency                                                           EUR
# levelOfDetail                                               BaseCurrency
# tradeID                                                                0
# balance                                                       25367.4400
# description                                          SPXW 25JUL23 4580 C
# activityCode                                                        SELL
# activityDescription                         Sell -1 SPXW 25JUL23 4580 C
# symbol                                             SPXW  230725C04580000
# underlyingSymbol                                                     SPX
# txInfo                 + 530 - Tx eingtragen Abschluss: 102.5350 Laut...
# opInfo                 Open-Trade SPXW 25JUL23 4580 C mit Gesamtpreis...
# Name: 29, dtype: object
# +++ 505 - Trade transactionID                  2022675485
# accountID                       U12047171
# tradeID                         578441108
# description           SPXW 25JUL23 4580 C
# IBCurrency                            USD
# conid                           640374222
# putCall                                 C
# tradePrice                         1.1500
# tradeDate             2023-07-25 00:00:00
# IBDateTime            2023-07-25 14:57:42
# strike                               4580
# expiryDate            2023-07-25 00:00:00
# action                                STO
# notes
# openClose                            Open
# quantity                               -1
# buySell                              SELL
# symbol              SPXW  230725C04580000
# underlyingSymbol                      SPX
# symbolSort          SPX C - 20230725 4580
# assetCategory                         OPT
# multiplier                            100
# transactionType                 ExchTrade
# cost                                 0.00
# fifoPnlRealized                      0.00
# capitalGainsPnl                      0.00
# fxPnl                                0.00
# fxRateToBase                         0.00
# ibCommission                        -1.64
# Name: 0, dtype: object zu Statement gefunden
# +++ opGetPositionCountSELECT COUNT(*) AS anzahl FROM openPositions WHERE conid = 640374222
#    anzahl
# 0       0
# +++ - 206 - GetPositionsCount WHERE conid = 640374222 --> Anzahl 0    0
# Name: anzahl, dtype: int64
# + 517 opGetPositionsCount (trade.conid) > Trade Quantity = -1  Anzahl Offene Positionen: 0    0
# Name: anzahl, dtype: int64 - Welcher Typ: ? Open
# # - 513 - Insert Tax Statment
# ++ 333 - tx Insert Tax Statment Category: OPT OpenClose: Open  buySell:  SELL
# +++ TX Insert Im Zustand Open, Amount ist 102.5350  TradeOPen: Open
# INSERT INTO taxStatements (transactionID, symbol, underlyingSymbol, conid, description, activityDescription, assetCategory, openClose, tradeDate, taxYear, buySell, putCall, baseAmount, baseCurrency, baseBalance, fifoPnlRealized, taxFiFoResult, quantity, comment, datensatz, fxRateToBase, action ) Values ( %s, %s, %s, %s, %s, %s, %s,          %s, %s, %s, %s, %s, %s, %s, %s , %s,          %s, %s, %s, %s, %s , %s )
# in: txInsertTax Statement Open SPXW 25JUL23 4580 C mit Gesamtpreis 102.5350 mit Anzahl: -1 eingetragen FiFo 102.5350
# +++ 217 -  updateStatmentField op Info  UPDATE statements SET txInfo = '+ 530 - Tx eingtragen Abschluss: 102.5350 Laut fifoPnlRealized  0.00 Erfolg oder nicht?    '     WHERE transactionID = 2022675485 AND  levelOfDetail = 'BaseCurrency'
# +++ txUpadte Tax StatmentCategory: OPT OpenClose: Open  buySell:  SELL
# UPDATE taxStatements SET taxAmountStillhalterGewinn = 102.5350 WHERE transactionID = 2022675485
#
# + 493 - ++++++++++ Datensatz 31 ++ID: 545 ++++  Buy 1 SPXW 25JUL23 4570 P  +++++ Max = 30++++ Start 1+++++
# + 495 - +++++++Abbruch wegen max 30
#  FERTIG mit 31 Datensätzen

# %%
dbConn.commit()
dbConn.close()



# 09.07.23 BG 
#qif.to_qif(".\money.qif")
